# %% [markdown]
# # 1. Imports

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

import os
import numpy as np
from torchvision import datasets, models, transforms

from torchvision.models import resnet18, ResNet18_Weights
import torch.optim as optim


import random
import pandas as pd
import pickle

from sklearn.model_selection import train_test_split


from sklearn.model_selection import GroupKFold
from sklearn.model_selection import StratifiedGroupKFold


from codes.utils import stratified_train_test_group_kfold
from codes.utils import model_test_classification
from codes.utils import accuracy_nnrank
from codes.utils import cnn_nnrank_cross_val_final_test

from codes.regression_codes import cnn_nnrank_gridsearch


torch.backends.cudnn.deterministic = True
random.seed(1)
torch.manual_seed(1)
torch.cuda.manual_seed(1)
np.random.seed(1)

use_cuda = torch.cuda.is_available()
device = torch.device("cuda:0" if use_cuda else "cpu")
torch.backends.cudnn.benchmark = True

# %% [markdown]
# # 2. Data

# %%
with open("Data/MoS2_Analysis_Processed_Data2", "rb") as fp:   # Unpickling
  MoS2_data = pickle.load(fp)

df = pd.DataFrame(MoS2_data)
T = df['T']

T_classes = {900.0: 0, 950.0: 1, 1000.0: 2}
#print(MoS2_activities_substrate2['T'])
T_target = [T_classes[T[index]] for index, item in enumerate(T)]
sampleId = df['sampleId']
data_image = np.array([np.array(item) for item in df['image']])

#T_target = np.array(T_target).reshape(len(T_target),1)
print(len(T_target))

Data_CNN = data_image
print(Data_CNN.shape)
Data_CNN_rgb = np.repeat(Data_CNN[..., np.newaxis], 3, -1)
print(Data_CNN_rgb.shape)
Data_CNN_rgb = Data_CNN_rgb.transpose(0, 3, 1, 2)/255
print(Data_CNN_rgb.shape)



X = Data_CNN_rgb
Y = np.array(T_target)
groups = np.array(sampleId)


train_val_groups, train_val_X, train_val_Y, test_X, test_Y = stratified_train_test_group_kfold(X, Y, groups, n_splits=10, test_fold=0)


#Y = Y.flatten()



print(train_val_X.shape)
print(train_val_Y.shape)
print(test_X.shape)
print(test_Y.shape)


def pretrained_model(drop_out):
    
    model = models.resnet18(weights=ResNet18_Weights.DEFAULT)

    model.fc = nn.Sequential(nn.ReLU(),
                                 nn.Dropout(p=drop_out),
                                    nn.Linear(512, 100), #150, 50176
                                     nn.ReLU(),
                                     nn.Dropout(p=drop_out),
                                     nn.Linear(100, 3),
                                     nn.Sigmoid()
                                     )
    model.to(device)
    return model
# Out:
# 262
# (262, 224, 224)
# (262, 224, 224, 3)
# (262, 3, 224, 224)
# <class 'generator'>
# (235, 3, 224, 224)
# (235,)
# (27, 3, 224, 224)
# (27,)

# %%
# !mkdir -p 'Models/nnrank/ImageNet/aug3/CNN/'

# %% [markdown]
# # 3. Runing Cross-Validation

# %%
# the paramters below were optimized
# only the optimum parameters for the production model are used here

Learning_rate = [5e-5] #[1e-2, 5e-3, 1e-3, 5e-4, 1e-4, 1e-5, 5e-6] 
Drop_out = [0.2]#[0.2, 0.35, 0.5, 0.65, 0.75]
Batch_size = [100] #[24, 32, 100]

def cross_10_folds_cnn(train_val_X, train_val_Y):

    best_train = []
    best_val = []
 
    best_variables = []
    best_performance_record = []
    for fold in range(10):
        
        model_path = f'nnrank/ImageNet/aug3/CNN/{fold}_model.pth'
        group, train_X, train_Y, val_X, val_Y = stratified_train_test_group_kfold(train_val_X, train_val_Y, train_val_groups, n_splits=10, test_fold=fold)
        #train_X, val_X, train_Y, val_Y = train_test_split(train_val_X, train_val_Y, test_size=0.1,stratify=train_val_Y,random_state=fold+30)#42
        best_train_acc, best_val_acc, best_record, hyper=cnn_nnrank_gridsearch(train_X, train_Y, val_X, val_Y, Learning_rate,Drop_out, Batch_size, fold, model_path)#, epochs=34)
    
        best_train.append(best_train_acc)
        best_val.append(best_val_acc)

        best_variables.append(hyper)
        best_performance_record.append(best_record)

        print(f'fold: {fold} done!')
    return best_train, best_val, best_variables, best_performance_record


best_train, best_val, best_variables, best_performance_record = cross_10_folds_cnn(train_val_X, train_val_Y)
# Out:
# <class 'generator'>
# Epoch1: loss: 49.9988 val_loss: 16.3455
# Epoch2: loss: 44.5546 val_loss: 14.6204
# Epoch3: loss: 40.0436 val_loss: 14.0150
# Epoch4: loss: 36.6752 val_loss: 12.2559
# Epoch5: loss: 32.9435 val_loss: 12.3110
# Epoch6: loss: 31.6957 val_loss: 11.5994
# Epoch7: loss: 27.0584 val_loss: 10.0417
# Epoch8: loss: 24.7065 val_loss: 9.8446
# Epoch9: loss: 23.5530 val_loss: 8.7414
# Epoch10: loss: 21.2243 val_loss: 8.3128
# Epoch11: loss: 20.8283 val_loss: 8.0188
# Epoch12: loss: 17.5389 val_loss: 7.6006
# Epoch13: loss: 18.6593 val_loss: 8.1850
# Epoch14: loss: 16.2862 val_loss: 7.1365
# Epoch15: loss: 16.2115 val_loss: 6.8154
# Epoch16: loss: 14.0702 val_loss: 6.6374
# Epoch17: loss: 12.1854 val_loss: 7.1589
# Epoch18: loss: 13.8398 val_loss: 6.9241
# Epoch19: loss: 13.0860 val_loss: 6.9984
# Epoch20: loss: 13.0610 val_loss: 7.6753
# Epoch21: loss: 11.2394 val_loss: 7.4670
# Epoch22: loss: 9.9377 val_loss: 7.7166
# Epoch23: loss: 10.1676 val_loss: 6.5994
# Epoch24: loss: 9.9376 val_loss: 6.8313
# Epoch25: loss: 9.8013 val_loss: 6.3450
# Epoch26: loss: 7.8604 val_loss: 6.2568
# Epoch27: loss: 8.3697 val_loss: 6.3601
# Epoch28: loss: 8.9033 val_loss: 6.0605
# Epoch29: loss: 6.7227 val_loss: 6.4685
# Epoch30: loss: 7.1764 val_loss: 6.0056
# Epoch31: loss: 9.3185 val_loss: 7.1396
# Epoch32: loss: 7.2604 val_loss: 5.9973
# Epoch33: loss: 5.9888 val_loss: 6.4244
# Epoch34: loss: 7.0154 val_loss: 6.0363
# Epoch35: loss: 6.0574 val_loss: 6.0939
# Epoch36: loss: 6.2762 val_loss: 5.8840
# Epoch37: loss: 6.5834 val_loss: 6.2989
# Epoch38: loss: 5.0150 val_loss: 6.6629
# Epoch39: loss: 4.8284 val_loss: 5.1329
# Epoch40: loss: 3.8030 val_loss: 5.6982
# Epoch41: loss: 5.7255 val_loss: 6.7036
# Epoch42: loss: 4.6629 val_loss: 5.3090
# Epoch43: loss: 5.6653 val_loss: 5.6760
# Epoch44: loss: 4.0721 val_loss: 6.6634
# Epoch45: loss: 4.6984 val_loss: 6.6141
# Epoch46: loss: 5.0395 val_loss: 6.7550
# Epoch47: loss: 4.1411 val_loss: 6.7559
# Epoch48: loss: 3.6827 val_loss: 6.3327
# Epoch49: loss: 4.1222 val_loss: 6.0564
# Epoch50: loss: 4.1169 val_loss: 4.8543
# Epoch51: loss: 3.4843 val_loss: 5.5787
# Epoch52: loss: 2.2333 val_loss: 4.5584
# Epoch53: loss: 3.3555 val_loss: 4.7076
# Epoch54: loss: 2.3674 val_loss: 5.7182
# Epoch55: loss: 3.3298 val_loss: 4.3611
# Epoch56: loss: 2.6208 val_loss: 4.6514
# Epoch57: loss: 3.5622 val_loss: 6.0785
# Epoch58: loss: 3.1858 val_loss: 4.5390
# Epoch59: loss: 2.6664 val_loss: 5.7152
# Epoch60: loss: 2.2279 val_loss: 4.6719
# Epoch61: loss: 2.4058 val_loss: 6.1362
# Epoch62: loss: 1.8877 val_loss: 5.6695
# Epoch63: loss: 1.8640 val_loss: 6.3312
# Epoch64: loss: 2.9450 val_loss: 5.5215
# Epoch65: loss: 2.6985 val_loss: 6.2964
# Epoch66: loss: 2.1525 val_loss: 5.8699
# Epoch67: loss: 1.8670 val_loss: 6.1719
# Epoch68: loss: 1.3941 val_loss: 5.3329
# Epoch69: loss: 1.9469 val_loss: 5.8208
# Epoch70: loss: 2.9109 val_loss: 5.7867
# Epoch71: loss: 2.6072 val_loss: 5.1654
# Early stopped training at epoch 71
# Accuracy of the network on the 211 train images: 95.7 %
# Accuracy of the network on the 24 val images: 83.3 %
# fold: 0 done!
# <class 'generator'>
# Epoch1: loss: 51.3494 val_loss: 15.9722
# Epoch2: loss: 45.5615 val_loss: 15.2825
# Epoch3: loss: 43.1177 val_loss: 14.2673
# Epoch4: loss: 38.9474 val_loss: 12.3579
# Epoch5: loss: 35.3620 val_loss: 11.7916
# Epoch6: loss: 32.7179 val_loss: 11.8869
# Epoch7: loss: 29.5549 val_loss: 10.6154
# Epoch8: loss: 28.3740 val_loss: 9.6520
# Epoch9: loss: 25.3873 val_loss: 8.6104
# Epoch10: loss: 24.4908 val_loss: 8.7246
# Epoch11: loss: 21.9070 val_loss: 8.5657
# Epoch12: loss: 19.6974 val_loss: 8.2143
# Epoch13: loss: 19.3978 val_loss: 7.4683
# Epoch14: loss: 18.1057 val_loss: 7.6139
# Epoch15: loss: 18.0693 val_loss: 7.4549
# Epoch16: loss: 15.4450 val_loss: 6.8994
# Epoch17: loss: 16.4274 val_loss: 6.9529
# Epoch18: loss: 15.0040 val_loss: 7.1897
# Epoch19: loss: 12.7047 val_loss: 6.9086
# Epoch20: loss: 13.0506 val_loss: 7.4560
# Epoch21: loss: 13.0803 val_loss: 6.6882
# Epoch22: loss: 11.9484 val_loss: 6.8224
# Epoch23: loss: 11.8959 val_loss: 6.1695
# Epoch24: loss: 10.6000 val_loss: 7.0619
# Epoch25: loss: 10.7241 val_loss: 6.1017
# Epoch26: loss: 10.4299 val_loss: 6.3549
# Epoch27: loss: 9.7603 val_loss: 7.8846
# Epoch28: loss: 9.7865 val_loss: 6.3884
# Epoch29: loss: 8.4186 val_loss: 7.2361
# Epoch30: loss: 7.6832 val_loss: 7.2488
# Epoch31: loss: 8.0010 val_loss: 5.9599
# Epoch32: loss: 7.4529 val_loss: 6.3467
# Epoch33: loss: 8.0939 val_loss: 6.3646
# Epoch34: loss: 7.9805 val_loss: 6.9977
# Epoch35: loss: 7.4956 val_loss: 6.6167
# Epoch36: loss: 7.5906 val_loss: 6.2905
# Epoch37: loss: 5.9001 val_loss: 6.1583
# Epoch38: loss: 5.6731 val_loss: 6.4926
# Epoch39: loss: 4.9309 val_loss: 6.3583
# Epoch40: loss: 4.3055 val_loss: 7.1603
# Epoch41: loss: 4.9134 val_loss: 6.2395
# Epoch42: loss: 5.3774 val_loss: 5.8629
# Epoch43: loss: 5.2621 val_loss: 6.1561
# Epoch44: loss: 6.4129 val_loss: 5.1168
# Epoch45: loss: 3.6376 val_loss: 6.8055
# Epoch46: loss: 4.6617 val_loss: 5.2887
# Epoch47: loss: 3.2785 val_loss: 6.4156
# Epoch48: loss: 4.9509 val_loss: 5.8257
# Epoch49: loss: 3.4995 val_loss: 5.0913
# Epoch50: loss: 4.2031 val_loss: 5.4768
# Epoch51: loss: 5.2075 val_loss: 6.0893
# Epoch52: loss: 3.2261 val_loss: 6.0669
# Epoch53: loss: 3.6428 val_loss: 5.6394
# Epoch54: loss: 2.7275 val_loss: 5.6684
# Epoch55: loss: 3.7696 val_loss: 5.4795
# Epoch56: loss: 3.6868 val_loss: 6.2132
# Epoch57: loss: 2.6592 val_loss: 5.7983
# Epoch58: loss: 2.3522 val_loss: 5.3701
# Epoch59: loss: 2.7472 val_loss: 6.2389
# Epoch60: loss: 3.0258 val_loss: 6.5830
# Epoch61: loss: 3.6873 val_loss: 5.4458
# Epoch62: loss: 3.4076 val_loss: 5.6782
# Epoch63: loss: 2.9672 val_loss: 5.4322
# Epoch64: loss: 1.5226 val_loss: 6.3987
# Epoch65: loss: 2.1884 val_loss: 6.0077
# Early stopped training at epoch 65
# Accuracy of the network on the 211 train images: 98.6 %
# Accuracy of the network on the 24 val images: 75.0 %
# fold: 1 done!
# <class 'generator'>
# Epoch1: loss: 54.5947 val_loss: 16.0264
# Epoch2: loss: 49.8193 val_loss: 15.2854
# Epoch3: loss: 46.2738 val_loss: 14.3526
# Epoch4: loss: 42.4667 val_loss: 13.4826
# Epoch5: loss: 39.2807 val_loss: 13.0939
# Epoch6: loss: 35.1397 val_loss: 12.0969
# Epoch7: loss: 33.0091 val_loss: 11.2382
# Epoch8: loss: 30.1051 val_loss: 10.1422
# Epoch9: loss: 29.0319 val_loss: 10.0771
# Epoch10: loss: 26.0080 val_loss: 9.5231
# Epoch11: loss: 24.3273 val_loss: 9.3785
# Epoch12: loss: 23.5439 val_loss: 9.1609
# Epoch13: loss: 22.5157 val_loss: 8.4877
# Epoch14: loss: 20.8452 val_loss: 7.6975
# Epoch15: loss: 18.9397 val_loss: 8.0404
# Epoch16: loss: 18.4424 val_loss: 8.5026
# Epoch17: loss: 16.1137 val_loss: 8.1935
# Epoch18: loss: 16.3643 val_loss: 7.6085
# Epoch19: loss: 13.7061 val_loss: 8.0934
# Epoch20: loss: 13.6498 val_loss: 7.8648
# Epoch21: loss: 13.3357 val_loss: 7.6715
# Epoch22: loss: 11.6158 val_loss: 7.9656
# Epoch23: loss: 11.4137 val_loss: 7.4371
# Epoch24: loss: 11.1611 val_loss: 8.0470
# Epoch25: loss: 10.3716 val_loss: 7.8904
# Epoch26: loss: 8.9337 val_loss: 7.8292
# Epoch27: loss: 11.2215 val_loss: 8.9593
# Epoch28: loss: 10.2451 val_loss: 8.3742
# Epoch29: loss: 7.7519 val_loss: 8.5832
# Epoch30: loss: 8.7550 val_loss: 8.1836
# Epoch31: loss: 8.7970 val_loss: 7.5943
# Epoch32: loss: 7.2570 val_loss: 7.9028
# Epoch33: loss: 6.5054 val_loss: 7.6346
# Epoch34: loss: 5.7955 val_loss: 8.0749
# Epoch35: loss: 6.6795 val_loss: 7.6239
# Epoch36: loss: 6.8789 val_loss: 7.7873
# Epoch37: loss: 5.6086 val_loss: 7.9491
# Epoch38: loss: 4.9490 val_loss: 8.1695
# Epoch39: loss: 7.4850 val_loss: 7.8151
# Early stopped training at epoch 39
# Accuracy of the network on the 211 train images: 93.8 %
# Accuracy of the network on the 24 val images: 66.7 %
# fold: 2 done!
# <class 'generator'>
# Epoch1: loss: 46.2588 val_loss: 14.9535
# Epoch2: loss: 40.6063 val_loss: 13.9835
# Epoch3: loss: 38.0946 val_loss: 12.3533
# Epoch4: loss: 32.9580 val_loss: 11.1287
# Epoch5: loss: 30.6750 val_loss: 10.4386
# Epoch6: loss: 29.2530 val_loss: 9.9131
# Epoch7: loss: 25.2474 val_loss: 8.4898
# Epoch8: loss: 24.4204 val_loss: 8.8875
# Epoch9: loss: 23.4746 val_loss: 7.9700
# Epoch10: loss: 19.8827 val_loss: 8.2390
# Epoch11: loss: 18.8102 val_loss: 6.9039
# Epoch12: loss: 17.0084 val_loss: 7.3593
# Epoch13: loss: 16.0866 val_loss: 7.5055
# Epoch14: loss: 16.1339 val_loss: 6.7030
# Epoch15: loss: 14.3261 val_loss: 7.0955
# Epoch16: loss: 14.2476 val_loss: 7.6406
# Epoch17: loss: 13.2932 val_loss: 8.0215
# Epoch18: loss: 12.2929 val_loss: 7.4955
# Epoch19: loss: 11.7753 val_loss: 8.0441
# Epoch20: loss: 10.5771 val_loss: 7.7116
# Epoch21: loss: 11.2619 val_loss: 7.4148
# Epoch22: loss: 9.6650 val_loss: 7.5270
# Epoch23: loss: 10.7464 val_loss: 6.8322
# Epoch24: loss: 9.0676 val_loss: 6.9547
# Epoch25: loss: 9.5129 val_loss: 6.7847
# Epoch26: loss: 8.5499 val_loss: 7.1506
# Epoch27: loss: 8.1894 val_loss: 7.3283
# Epoch28: loss: 8.9640 val_loss: 7.8730
# Epoch29: loss: 5.8871 val_loss: 7.7720
# Epoch30: loss: 6.6973 val_loss: 7.5446
# Early stopped training at epoch 30
# Accuracy of the network on the 211 train images: 91.0 %
# Accuracy of the network on the 24 val images: 62.5 %
# fold: 3 done!
# <class 'generator'>
# Epoch1: loss: 51.4094 val_loss: 16.2658
# Epoch2: loss: 46.4084 val_loss: 15.0912
# Epoch3: loss: 42.5844 val_loss: 13.9050
# Epoch4: loss: 37.6193 val_loss: 12.1621
# Epoch5: loss: 32.8504 val_loss: 11.7649
# Epoch6: loss: 32.1984 val_loss: 10.8613
# Epoch7: loss: 28.0793 val_loss: 10.3305
# Epoch8: loss: 26.3125 val_loss: 9.0249
# Epoch9: loss: 24.5731 val_loss: 8.7813
# Epoch10: loss: 21.4843 val_loss: 8.2797
# Epoch11: loss: 19.7598 val_loss: 8.0628
# Epoch12: loss: 19.0454 val_loss: 7.9670
# Epoch13: loss: 17.1297 val_loss: 6.9196
# Epoch14: loss: 18.2926 val_loss: 6.3128
# Epoch15: loss: 15.1877 val_loss: 7.2529
# Epoch16: loss: 13.4815 val_loss: 8.5905
# Epoch17: loss: 13.3346 val_loss: 7.4116
# Epoch18: loss: 13.1167 val_loss: 6.6733
# Epoch19: loss: 11.8237 val_loss: 6.3990
# Epoch20: loss: 11.9513 val_loss: 7.5761
# Epoch21: loss: 10.4307 val_loss: 7.8451
# Epoch22: loss: 9.7123 val_loss: 8.1957
# Epoch23: loss: 9.4041 val_loss: 8.0656
# Epoch24: loss: 10.4273 val_loss: 7.8316
# Epoch25: loss: 11.5733 val_loss: 7.5708
# Epoch26: loss: 8.4803 val_loss: 7.1095
# Epoch27: loss: 7.5870 val_loss: 7.6628
# Epoch28: loss: 8.0866 val_loss: 6.3410
# Epoch29: loss: 7.1994 val_loss: 6.9410
# Epoch30: loss: 7.3972 val_loss: 7.3807
# Early stopped training at epoch 30
# Accuracy of the network on the 211 train images: 90.0 %
# Accuracy of the network on the 24 val images: 83.3 %
# fold: 4 done!
# <class 'generator'>
# Epoch1: loss: 55.7720 val_loss: 16.3828
# Epoch2: loss: 50.6109 val_loss: 14.5989
# Epoch3: loss: 45.0163 val_loss: 13.3295
# Epoch4: loss: 42.5477 val_loss: 12.6105
# Epoch5: loss: 38.4598 val_loss: 11.6120
# Epoch6: loss: 36.3374 val_loss: 10.7456
# Epoch7: loss: 32.4586 val_loss: 9.3115
# Epoch8: loss: 32.1672 val_loss: 9.5053
# Epoch9: loss: 28.8071 val_loss: 8.9154
# Epoch10: loss: 26.2026 val_loss: 7.9787
# Epoch11: loss: 26.1585 val_loss: 7.4365
# Epoch12: loss: 23.4153 val_loss: 7.5593
# Epoch13: loss: 22.2771 val_loss: 7.0299
# Epoch14: loss: 19.8692 val_loss: 7.2043
# Epoch15: loss: 19.6951 val_loss: 6.8424
# Epoch16: loss: 17.5272 val_loss: 6.4418
# Epoch17: loss: 19.3421 val_loss: 6.1652
# Epoch18: loss: 16.8488 val_loss: 6.0845
# Epoch19: loss: 14.7227 val_loss: 6.1139
# Epoch20: loss: 14.4688 val_loss: 6.1100
# Epoch21: loss: 12.5933 val_loss: 5.7967
# Epoch22: loss: 14.7440 val_loss: 5.6749
# Epoch23: loss: 11.2973 val_loss: 4.7753
# Epoch24: loss: 11.9074 val_loss: 5.5264
# Epoch25: loss: 11.8781 val_loss: 5.4700
# Epoch26: loss: 11.4097 val_loss: 4.3808
# Epoch27: loss: 10.8024 val_loss: 5.0943
# Epoch28: loss: 9.6268 val_loss: 4.9094
# Epoch29: loss: 8.3676 val_loss: 6.8556
# Epoch30: loss: 8.9669 val_loss: 5.7718
# Epoch31: loss: 7.9025 val_loss: 4.7662
# Epoch32: loss: 7.8305 val_loss: 6.1299
# Epoch33: loss: 7.8814 val_loss: 5.4064
# Epoch34: loss: 5.9949 val_loss: 5.2177
# Epoch35: loss: 5.9258 val_loss: 6.7418
# Epoch36: loss: 6.2138 val_loss: 4.6061
# Epoch37: loss: 6.6643 val_loss: 6.2791
# Epoch38: loss: 6.0311 val_loss: 5.4911
# Epoch39: loss: 6.1717 val_loss: 6.2061
# Epoch40: loss: 6.1467 val_loss: 6.6124
# Epoch41: loss: 5.1958 val_loss: 5.0431
# Epoch42: loss: 6.2414 val_loss: 5.2463
# Early stopped training at epoch 42
# Accuracy of the network on the 212 train images: 95.3 %
# Accuracy of the network on the 23 val images: 65.2 %
# fold: 5 done!
# <class 'generator'>
# Epoch1: loss: 51.4505 val_loss: 14.8322
# Epoch2: loss: 46.1586 val_loss: 12.7152
# Epoch3: loss: 40.6271 val_loss: 12.1075
# Epoch4: loss: 37.2594 val_loss: 10.6417
# Epoch5: loss: 34.7733 val_loss: 9.7556
# Epoch6: loss: 30.1790 val_loss: 9.5436
# Epoch7: loss: 27.0547 val_loss: 8.9346
# Epoch8: loss: 25.1258 val_loss: 9.4538
# Epoch9: loss: 23.9678 val_loss: 9.9554
# Epoch10: loss: 20.7492 val_loss: 9.7511
# Epoch11: loss: 19.2512 val_loss: 9.1002
# Epoch12: loss: 19.1740 val_loss: 9.3333
# Epoch13: loss: 17.1394 val_loss: 9.0452
# Epoch14: loss: 17.8565 val_loss: 7.7305
# Epoch15: loss: 16.0529 val_loss: 8.4786
# Epoch16: loss: 16.1757 val_loss: 7.6197
# Epoch17: loss: 13.7094 val_loss: 7.5245
# Epoch18: loss: 14.3866 val_loss: 7.3008
# Epoch19: loss: 11.2452 val_loss: 8.1670
# Epoch20: loss: 11.6820 val_loss: 7.6865
# Epoch21: loss: 11.6276 val_loss: 8.6562
# Epoch22: loss: 10.1415 val_loss: 7.1227
# Epoch23: loss: 9.7049 val_loss: 6.9134
# Epoch24: loss: 9.1554 val_loss: 7.0597
# Epoch25: loss: 9.7794 val_loss: 6.8601
# Epoch26: loss: 10.2198 val_loss: 7.9177
# Epoch27: loss: 7.8209 val_loss: 8.0085
# Epoch28: loss: 8.0467 val_loss: 7.5008
# Epoch29: loss: 6.3887 val_loss: 7.5469
# Epoch30: loss: 6.9772 val_loss: 6.4105
# Epoch31: loss: 6.3175 val_loss: 7.7276
# Epoch32: loss: 6.1958 val_loss: 6.2912
# Epoch33: loss: 5.8888 val_loss: 6.7659
# Epoch34: loss: 7.0236 val_loss: 8.6763
# Epoch35: loss: 6.7782 val_loss: 7.5345
# Epoch36: loss: 6.3393 val_loss: 7.7257
# Epoch37: loss: 6.6473 val_loss: 7.9472
# Epoch38: loss: 4.9452 val_loss: 7.6082
# Epoch39: loss: 6.0710 val_loss: 8.5644
# Epoch40: loss: 5.3428 val_loss: 7.9586
# Epoch41: loss: 5.1356 val_loss: 6.2654
# Epoch42: loss: 5.0206 val_loss: 7.9174
# Epoch43: loss: 5.8996 val_loss: 6.7958
# Epoch44: loss: 4.7676 val_loss: 7.5136
# Epoch45: loss: 3.6146 val_loss: 6.7694
# Epoch46: loss: 4.5525 val_loss: 7.1792
# Epoch47: loss: 4.5063 val_loss: 7.4476
# Epoch48: loss: 3.7485 val_loss: 7.8523
# Epoch49: loss: 3.4880 val_loss: 6.4103
# Epoch50: loss: 4.9161 val_loss: 5.8235
# Epoch51: loss: 4.3664 val_loss: 7.7804
# Epoch52: loss: 3.7998 val_loss: 7.9005
# Epoch53: loss: 2.7734 val_loss: 7.9329
# Epoch54: loss: 3.8930 val_loss: 8.3636
# Epoch55: loss: 3.5116 val_loss: 8.6937
# Epoch56: loss: 2.6765 val_loss: 8.5163
# Epoch57: loss: 2.9868 val_loss: 7.5711
# Epoch58: loss: 4.2153 val_loss: 7.0603
# Epoch59: loss: 3.0304 val_loss: 7.8004
# Epoch60: loss: 3.0020 val_loss: 7.8551
# Epoch61: loss: 2.0256 val_loss: 9.0688
# Epoch62: loss: 2.4579 val_loss: 8.2458
# Epoch63: loss: 2.8183 val_loss: 7.1571
# Epoch64: loss: 3.0415 val_loss: 7.5202
# Epoch65: loss: 2.2491 val_loss: 7.2626
# Epoch66: loss: 1.8833 val_loss: 7.5799
# Early stopped training at epoch 66
# Accuracy of the network on the 212 train images: 100.0 %
# Accuracy of the network on the 23 val images: 65.2 %
# fold: 6 done!
# <class 'generator'>
# Epoch1: loss: 46.5948 val_loss: 12.7271
# Epoch2: loss: 40.4034 val_loss: 11.7036
# Epoch3: loss: 37.8859 val_loss: 10.8963
# Epoch4: loss: 35.8428 val_loss: 9.4976
# Epoch5: loss: 33.6966 val_loss: 10.2496
# Epoch6: loss: 29.4880 val_loss: 8.2912
# Epoch7: loss: 27.2781 val_loss: 9.1713
# Epoch8: loss: 26.0946 val_loss: 8.3532
# Epoch9: loss: 24.6714 val_loss: 7.6810
# Epoch10: loss: 20.7877 val_loss: 8.1147
# Epoch11: loss: 20.0020 val_loss: 7.7957
# Epoch12: loss: 18.8626 val_loss: 8.1407
# Epoch13: loss: 17.2942 val_loss: 7.7923
# Epoch14: loss: 17.0183 val_loss: 7.4794
# Epoch15: loss: 16.1398 val_loss: 7.3828
# Epoch16: loss: 14.9043 val_loss: 8.3390
# Epoch17: loss: 13.5521 val_loss: 7.2889
# Epoch18: loss: 12.0524 val_loss: 7.4985
# Epoch19: loss: 11.8574 val_loss: 6.4492
# Epoch20: loss: 12.2722 val_loss: 7.0342
# Epoch21: loss: 12.7325 val_loss: 8.2401
# Epoch22: loss: 11.3231 val_loss: 8.9205
# Epoch23: loss: 10.7474 val_loss: 9.6787
# Epoch24: loss: 9.4253 val_loss: 9.2457
# Epoch25: loss: 11.6824 val_loss: 7.5926
# Epoch26: loss: 8.6423 val_loss: 7.3427
# Epoch27: loss: 8.0647 val_loss: 7.2226
# Epoch28: loss: 6.6838 val_loss: 7.0326
# Epoch29: loss: 7.6856 val_loss: 7.2100
# Epoch30: loss: 7.4561 val_loss: 6.6527
# Epoch31: loss: 5.6423 val_loss: 7.5522
# Epoch32: loss: 7.3288 val_loss: 7.9484
# Epoch33: loss: 6.5786 val_loss: 7.7790
# Epoch34: loss: 6.5599 val_loss: 8.4121
# Epoch35: loss: 6.0935 val_loss: 8.0459
# Early stopped training at epoch 35
# Accuracy of the network on the 212 train images: 91.5 %
# Accuracy of the network on the 23 val images: 65.2 %
# fold: 7 done!
# <class 'generator'>
# Epoch1: loss: 52.8255 val_loss: 16.6281
# Epoch2: loss: 47.1678 val_loss: 15.4691
# Epoch3: loss: 42.5225 val_loss: 14.6422
# Epoch4: loss: 39.1465 val_loss: 13.5276
# Epoch5: loss: 36.0662 val_loss: 12.4244
# Epoch6: loss: 33.0254 val_loss: 12.7277
# Epoch7: loss: 30.5599 val_loss: 11.7937
# Epoch8: loss: 29.2077 val_loss: 11.7148
# Epoch9: loss: 25.1856 val_loss: 10.1418
# Epoch10: loss: 24.0722 val_loss: 11.3024
# Epoch11: loss: 21.6039 val_loss: 10.2615
# Epoch12: loss: 21.2652 val_loss: 10.2687
# Epoch13: loss: 19.1636 val_loss: 10.1561
# Epoch14: loss: 19.2804 val_loss: 10.6203
# Epoch15: loss: 18.2745 val_loss: 10.4133
# Epoch16: loss: 16.6535 val_loss: 9.0826
# Epoch17: loss: 15.7353 val_loss: 9.3131
# Epoch18: loss: 14.9265 val_loss: 8.3446
# Epoch19: loss: 15.3527 val_loss: 9.0379
# Epoch20: loss: 13.6224 val_loss: 9.6007
# Epoch21: loss: 11.9708 val_loss: 9.6503
# Epoch22: loss: 11.2719 val_loss: 9.3543
# Epoch23: loss: 11.0010 val_loss: 9.1768
# Epoch24: loss: 12.2225 val_loss: 8.9492
# Epoch25: loss: 10.5857 val_loss: 9.7082
# Epoch26: loss: 11.2853 val_loss: 9.6765
# Epoch27: loss: 9.8979 val_loss: 10.5952
# Epoch28: loss: 9.1126 val_loss: 10.0058
# Epoch29: loss: 8.4183 val_loss: 10.3270
# Epoch30: loss: 8.2335 val_loss: 10.7917
# Epoch31: loss: 8.1611 val_loss: 9.3573
# Epoch32: loss: 7.6048 val_loss: 9.1747
# Epoch33: loss: 7.6443 val_loss: 10.1056
# Epoch34: loss: 7.9591 val_loss: 9.6426
# Early stopped training at epoch 34
# Accuracy of the network on the 212 train images: 95.3 %
# Accuracy of the network on the 23 val images: 43.5 %
# fold: 8 done!
# <class 'generator'>
# Epoch1: loss: 52.9776 val_loss: 15.9496
# Epoch2: loss: 47.1545 val_loss: 14.4345
# Epoch3: loss: 42.6484 val_loss: 13.4419
# Epoch4: loss: 39.5273 val_loss: 12.4633
# Epoch5: loss: 35.0107 val_loss: 11.4256
# Epoch6: loss: 33.3210 val_loss: 11.0864
# Epoch7: loss: 29.1674 val_loss: 9.5302
# Epoch8: loss: 27.6831 val_loss: 8.7675
# Epoch9: loss: 25.3884 val_loss: 8.3671
# Epoch10: loss: 24.2676 val_loss: 7.5588
# Epoch11: loss: 21.8347 val_loss: 8.3148
# Epoch12: loss: 19.6232 val_loss: 8.3595
# Epoch13: loss: 19.4197 val_loss: 8.0681
# Epoch14: loss: 18.1079 val_loss: 6.6931
# Epoch15: loss: 17.4217 val_loss: 7.3857
# Epoch16: loss: 16.7004 val_loss: 7.1392
# Epoch17: loss: 15.9121 val_loss: 6.5832
# Epoch18: loss: 14.7923 val_loss: 6.8208
# Epoch19: loss: 13.8385 val_loss: 7.6782
# Epoch20: loss: 13.5991 val_loss: 6.7818
# Epoch21: loss: 13.2328 val_loss: 6.6014
# Epoch22: loss: 11.7737 val_loss: 7.5243
# Epoch23: loss: 12.6852 val_loss: 6.4904
# Epoch24: loss: 10.4742 val_loss: 7.0180
# Epoch25: loss: 10.2458 val_loss: 6.3048
# Epoch26: loss: 10.4134 val_loss: 7.1814
# Epoch27: loss: 10.5587 val_loss: 6.1279
# Epoch28: loss: 7.8316 val_loss: 6.5499
# Epoch29: loss: 11.0077 val_loss: 5.7403
# Epoch30: loss: 8.8182 val_loss: 5.5999
# Epoch31: loss: 8.5791 val_loss: 6.9112
# Epoch32: loss: 6.8879 val_loss: 6.4609
# Epoch33: loss: 8.1732 val_loss: 6.7389
# Epoch34: loss: 7.8253 val_loss: 6.5678
# Epoch35: loss: 6.9935 val_loss: 5.8675
# Epoch36: loss: 5.4529 val_loss: 6.1874
# Epoch37: loss: 5.6619 val_loss: 5.0415
# Epoch38: loss: 7.5454 val_loss: 5.8837
# Epoch39: loss: 5.8017 val_loss: 6.3355
# Epoch40: loss: 5.8082 val_loss: 5.4460
# Epoch41: loss: 6.1262 val_loss: 7.5900
# Epoch42: loss: 4.8705 val_loss: 5.8727
# Epoch43: loss: 5.5110 val_loss: 4.9295
# Epoch44: loss: 4.8132 val_loss: 5.9695
# Epoch45: loss: 5.5696 val_loss: 5.5459
# Epoch46: loss: 4.7078 val_loss: 6.5946
# Epoch47: loss: 4.8390 val_loss: 6.4692
# Epoch48: loss: 4.6737 val_loss: 5.6630
# Epoch49: loss: 5.6596 val_loss: 4.5217
# Epoch50: loss: 4.4942 val_loss: 5.7637
# Epoch51: loss: 2.8579 val_loss: 5.2488
# Epoch52: loss: 3.1561 val_loss: 5.2244
# Epoch53: loss: 2.9369 val_loss: 5.9392
# Epoch54: loss: 3.8744 val_loss: 5.1681
# Epoch55: loss: 3.2831 val_loss: 4.5186
# Epoch56: loss: 3.4349 val_loss: 4.4510
# Epoch57: loss: 3.3570 val_loss: 7.5171
# Epoch58: loss: 2.5530 val_loss: 6.0695
# Epoch59: loss: 3.3317 val_loss: 5.7798
# Epoch60: loss: 3.2624 val_loss: 6.0320
# Epoch61: loss: 1.6950 val_loss: 5.1176
# Epoch62: loss: 2.4209 val_loss: 6.7391
# Epoch63: loss: 3.6905 val_loss: 6.9551
# Epoch64: loss: 2.7817 val_loss: 6.7186
# Epoch65: loss: 2.7147 val_loss: 5.6962
# Epoch66: loss: 1.8069 val_loss: 5.7167
# Epoch67: loss: 2.4225 val_loss: 6.6707
# Epoch68: loss: 2.0338 val_loss: 5.9337
# Epoch69: loss: 2.6880 val_loss: 5.3641
# Epoch70: loss: 1.9589 val_loss: 6.5027
# Epoch71: loss: 2.1257 val_loss: 7.0668
# Epoch72: loss: 2.2571 val_loss: 5.3606
# Early stopped training at epoch 72
# Accuracy of the network on the 212 train images: 100.0 %
# Accuracy of the network on the 23 val images: 87.0 %
# fold: 9 done!

# %% [markdown]
# # 4. Test Models

# %%
trained_model = pretrained_model(0.2)
root_path = f'nnrank/ImageNet/aug3/CNN'

best_test, confusion_matrix_test = cnn_nnrank_cross_val_final_test(trained_model, test_X, test_Y, 'test', root_path)


print(best_test)
print(f'test_acc_mean: {np.mean(best_test) :.3f}, std: {np.std(best_test) :.3f}')
print("......")

def cm_to_plot(best_test):

    max_test = np.max(best_test)
    idx_cm = []
    for index, item in enumerate(best_test):
        if item == max_test:
            idx_cm.append(index)

    print('idx_cm: ', idx_cm)
    print('max_test_acc: ', max_test)

    print(confusion_matrix_test[idx_cm[0]])
cm_to_plot(best_test)
print('5th confusion matrix: ', [list(item) for item in confusion_matrix_test[4]])


cm_list = []
for cm in confusion_matrix_test:
    cm_list.append([list(item) for item in cm])
#print(cm_list)

print(len(cm_list))
print('avg cm: ', [list(item) for item in np.mean(cm_list, axis=0)])
# Out:
# Accuracy of the network on the 27 test images: 63.0 %
# Accuracy of the network on the 27 test images: 59.3 %
# Accuracy of the network on the 27 test images: 74.1 %
# Accuracy of the network on the 27 test images: 55.6 %
# Accuracy of the network on the 27 test images: 63.0 %
# Accuracy of the network on the 27 test images: 66.7 %
# Accuracy of the network on the 27 test images: 77.8 %
# Accuracy of the network on the 27 test images: 70.4 %
# Accuracy of the network on the 27 test images: 74.1 %
# Accuracy of the network on the 27 test images: 74.1 %
# [62.96296296296296, 59.25925925925926, 74.07407407407408, 55.55555555555556, 62.96296296296296, 66.66666666666667, 77.77777777777777, 70.37037037037037, 74.07407407407408, 74.07407407407408]
# test_acc_mean: 67.778, std: 7.037
# ......
# idx_cm:  [6]
# max_test_acc:  77.77777777777777
# [[ 2  1  0]
#  [ 1 10  2]
#  [ 0  2  9]]
# 5th confusion matrix:  [[1, 2, 0], [3, 7, 3], [1, 1, 9]]
# 10
# avg cm:  [[1.3, 1.7, 0.0], [2.3, 8.8, 1.9], [0.1, 2.7, 8.2]]

# %%
'Models/nnrank/ImageNet/aug3/CNN/'
