# %% [markdown]
# # 1. Imports

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

import os
import numpy as np
from torchvision import datasets, models, transforms

from torchvision.models import resnet18, ResNet18_Weights
import torch.optim as optim


import random
import pandas as pd
import pickle

from sklearn.model_selection import train_test_split


from sklearn.model_selection import GroupKFold
from sklearn.model_selection import StratifiedGroupKFold
from imblearn.over_sampling import RandomOverSampler



from codes.utils import stratified_train_test_group_kfold
from codes.utils import model_test_classification
from codes.utils import accuracy_classification
from codes.utils import mlp_nnrank_cross_val_final_test

from codes.regression_codes import mlp_nnrank_gridsearch


torch.backends.cudnn.deterministic = True
random.seed(1)
torch.manual_seed(1)
torch.cuda.manual_seed(1)
np.random.seed(1)

use_cuda = torch.cuda.is_available()
device = torch.device("cuda:0" if use_cuda else "cpu")
torch.backends.cudnn.benchmark = True

# %% [markdown]
# # 2. Data

# %%
with open("Data/MoS2_Analysis_Data_trained2", "rb") as fp:   # Unpickling
    MoS2_Proj1_Class_Data = pickle.load(fp)

#features = MoS2_ImageNet_100_data[0]
df = pd.DataFrame(MoS2_Proj1_Class_Data)
print(df.keys())
T_dict= {900:0, 950:1, 1000:2}
T_target = np.array([T_dict[item] for item in df['T']])

features = np.array(list(df['ImageNet']))
sampleId = np.array(list(df['sampleId']))

X = features
Y = np.array(T_target)
#Y = Y.reshape(-1, 1)
groups = np.array(sampleId)

train_val_groups, train_val_X, train_val_Y, test_X, test_Y = stratified_train_test_group_kfold(X, Y, groups, n_splits=10, test_fold=0)


#Y = Y.flatten()

oversample = RandomOverSampler(sampling_strategy='not majority')

print(train_val_X.shape)
print(train_val_Y.shape)
print(test_X.shape)
print(test_Y.shape)
# Out:
# Index(['sampleId', 'sampleLabel', 'image', 'T', 'ImageNet', 'MicroNet'], dtype='object')
# <class 'generator'>
# (235, 100)
# (235,)
# (27, 100)
# (27,)

# %%
print(Y[0])
# Out:
# 2

# %% [markdown]
# # 3. Runing Cross-Validation

# %%
#!mkdir -p 'Models/nnrank/ImageNet/aug3/MLP'

# %%
# the paramters below were optimized
#this run is only for the production model, only the optimized hyperparameters
                        
Learning_rate = [0.01]
Drop_out = [0.35]#[0.0, 0.2, 0.35, 0.5]
Batch_size = [32]#[16, 32, 100]
L1 = [600]#[600, 400, 300, 200]
L2 = [150]# [150, 100, 50]

def cross_10_folds_mlp(train_val_X, train_val_Y):

    best_train = []
    best_val = []
    best_variables = []
    best_performance_record = []
    for fold in range(10):
        
        model_path = f'nnrank/ImageNet/aug3/MLP/{fold}_model.pth'
        group, train_X, train_Y, val_X, val_Y = stratified_train_test_group_kfold(train_val_X, train_val_Y, train_val_groups, n_splits=10, test_fold=fold)
        train_X, train_Y = oversample.fit_resample(train_X, train_Y)
        
        #train_X, val_X, train_Y, val_Y = train_test_split(train_val_X, train_val_Y, test_size=0.1,stratify=train_val_Y,random_state=fold+30)#42
        best_train_acc, best_val_acc, best_record, hyper=mlp_nnrank_gridsearch(train_X, train_Y, val_X, val_Y,Learning_rate, L1, L2, Drop_out,Batch_size, fold, model_path)
        #best_train_acc, best_val_acc, trainf1, valf1, best_perf_record, hyper=cnn_class_train_fn(train_X, train_Y, val_X, val_Y, Learning_rate, Batch_size, fold)

        best_train.append(best_train_acc)
        best_val.append(best_val_acc)
        best_variables.append(hyper)
        best_performance_record.append(best_record)

        print(f'fold: {fold} done!')
    return best_train, best_val, best_variables, best_performance_record


best_train, best_val, best_variables, best_performance_record = cross_10_folds_mlp(train_val_X, train_val_Y)
# Out:
# <class 'generator'>
# Epoch1: loss: 16.0200 val_loss: 10.8593
# Epoch2: loss: 9.4872 val_loss: 5.5211
# Epoch3: loss: 8.3409 val_loss: 5.5562
# Epoch4: loss: 6.9869 val_loss: 4.9315
# Epoch5: loss: 5.9337 val_loss: 4.5624
# Epoch6: loss: 5.5023 val_loss: 5.0979
# Epoch7: loss: 4.8424 val_loss: 4.6525
# Epoch8: loss: 3.9628 val_loss: 5.4996
# Epoch9: loss: 3.6023 val_loss: 4.7171
# Epoch10: loss: 3.2741 val_loss: 4.8002
# Epoch11: loss: 2.5940 val_loss: 6.1741
# Epoch12: loss: 2.8674 val_loss: 4.3993
# Epoch13: loss: 1.8128 val_loss: 5.8599
# Epoch14: loss: 2.6041 val_loss: 5.6071
# Epoch15: loss: 1.8053 val_loss: 5.5615
# Epoch16: loss: 1.1959 val_loss: 6.8277
# Epoch17: loss: 1.4660 val_loss: 4.2645
# Epoch18: loss: 1.5836 val_loss: 5.3498
# Epoch19: loss: 1.1581 val_loss: 5.5801
# Epoch20: loss: 1.0777 val_loss: 5.7946
# Epoch21: loss: 0.8902 val_loss: 5.6260
# Epoch22: loss: 1.0068 val_loss: 5.8403
# Epoch23: loss: 1.3318 val_loss: 5.1780
# Epoch24: loss: 0.9607 val_loss: 5.4712
# Epoch25: loss: 1.3151 val_loss: 5.1758
# Epoch26: loss: 1.1861 val_loss: 5.0619
# Epoch27: loss: 1.3963 val_loss: 6.5157
# Epoch28: loss: 1.0929 val_loss: 5.6965
# Epoch29: loss: 0.5233 val_loss: 5.6723
# Epoch30: loss: 0.5375 val_loss: 6.3619
# Epoch31: loss: 0.5521 val_loss: 5.1534
# Epoch32: loss: 0.9943 val_loss: 5.7320
# Epoch33: loss: 0.5662 val_loss: 5.1315
# Epoch34: loss: 0.4779 val_loss: 5.6242
# Epoch35: loss: 0.5665 val_loss: 6.8694
# Epoch36: loss: 0.5057 val_loss: 6.4074
# Epoch37: loss: 0.8375 val_loss: 5.6780
# Epoch38: loss: 0.8174 val_loss: 7.4984
# Early stopped training at epoch 38
# Accuracy of the network on the 315 train images: 98.4 %
# Accuracy of the network on the 24 val images: 66.7 %
# fold: 0 done!
# <class 'generator'>
# Epoch1: loss: 13.5269 val_loss: 10.5723
# Epoch2: loss: 10.0362 val_loss: 7.4099
# Epoch3: loss: 7.6460 val_loss: 8.1156
# Epoch4: loss: 7.6920 val_loss: 6.7181
# Epoch5: loss: 7.3981 val_loss: 6.4181
# Epoch6: loss: 6.6525 val_loss: 7.5230
# Epoch7: loss: 5.5138 val_loss: 8.0356
# Epoch8: loss: 4.6419 val_loss: 6.0414
# Epoch9: loss: 3.6113 val_loss: 4.6256
# Epoch10: loss: 4.0704 val_loss: 8.1538
# Epoch11: loss: 5.4191 val_loss: 7.4716
# Epoch12: loss: 4.5106 val_loss: 6.9610
# Epoch13: loss: 3.4818 val_loss: 4.1118
# Epoch14: loss: 2.1278 val_loss: 6.3728
# Epoch15: loss: 2.1631 val_loss: 4.7462
# Epoch16: loss: 1.8583 val_loss: 4.8569
# Epoch17: loss: 1.5907 val_loss: 6.0329
# Epoch18: loss: 2.0273 val_loss: 3.7710
# Epoch19: loss: 1.8961 val_loss: 6.5374
# Epoch20: loss: 1.5402 val_loss: 4.0961
# Epoch21: loss: 1.3146 val_loss: 2.3561
# Epoch22: loss: 1.2331 val_loss: 5.2478
# Epoch23: loss: 1.2944 val_loss: 4.5319
# Epoch24: loss: 2.4570 val_loss: 3.6748
# Epoch25: loss: 1.3370 val_loss: 5.7158
# Epoch26: loss: 1.5751 val_loss: 5.9520
# Epoch27: loss: 0.8618 val_loss: 5.7094
# Epoch28: loss: 0.7615 val_loss: 5.0566
# Epoch29: loss: 0.6731 val_loss: 6.1613
# Epoch30: loss: 0.6912 val_loss: 4.5662
# Epoch31: loss: 1.2952 val_loss: 5.9528
# Epoch32: loss: 2.0741 val_loss: 3.2417
# Epoch33: loss: 1.7114 val_loss: 5.7030
# Epoch34: loss: 1.0733 val_loss: 5.4218
# Epoch35: loss: 0.7970 val_loss: 10.8110
# Epoch36: loss: 3.4271 val_loss: 6.6907
# Epoch37: loss: 2.6389 val_loss: 5.1577
# Epoch38: loss: 1.6146 val_loss: 5.7573
# Epoch39: loss: 1.1996 val_loss: 6.8217
# Epoch40: loss: 1.1118 val_loss: 5.8194
# Epoch41: loss: 0.7413 val_loss: 4.2590
# Epoch42: loss: 0.7766 val_loss: 6.9758
# Early stopped training at epoch 42
# Accuracy of the network on the 318 train images: 97.8 %
# Accuracy of the network on the 24 val images: 70.8 %
# fold: 1 done!
# <class 'generator'>
# Epoch1: loss: 13.8679 val_loss: 12.0408
# Epoch2: loss: 9.9119 val_loss: 6.1741
# Epoch3: loss: 7.2248 val_loss: 7.9202
# Epoch4: loss: 6.3597 val_loss: 7.4612
# Epoch5: loss: 5.1931 val_loss: 7.6038
# Epoch6: loss: 4.6759 val_loss: 6.7800
# Epoch7: loss: 4.2225 val_loss: 7.2312
# Epoch8: loss: 2.8471 val_loss: 6.6570
# Epoch9: loss: 2.6681 val_loss: 6.8047
# Epoch10: loss: 2.3665 val_loss: 6.6918
# Epoch11: loss: 1.8907 val_loss: 6.5541
# Epoch12: loss: 2.1667 val_loss: 6.7334
# Epoch13: loss: 2.5257 val_loss: 5.9386
# Epoch14: loss: 2.3600 val_loss: 7.4787
# Epoch15: loss: 2.2923 val_loss: 8.9828
# Epoch16: loss: 3.0529 val_loss: 6.2504
# Epoch17: loss: 1.3568 val_loss: 7.4614
# Epoch18: loss: 1.4847 val_loss: 7.4218
# Epoch19: loss: 1.0506 val_loss: 8.8033
# Epoch20: loss: 1.3539 val_loss: 8.1576
# Epoch21: loss: 1.5173 val_loss: 7.0212
# Epoch22: loss: 1.0333 val_loss: 6.8416
# Epoch23: loss: 1.1253 val_loss: 7.6758
# Epoch24: loss: 1.0557 val_loss: 9.9192
# Epoch25: loss: 0.8529 val_loss: 10.3275
# Epoch26: loss: 1.0132 val_loss: 7.4082
# Epoch27: loss: 0.8117 val_loss: 6.9671
# Epoch28: loss: 0.9476 val_loss: 9.2509
# Epoch29: loss: 0.6423 val_loss: 8.1174
# Epoch30: loss: 0.5608 val_loss: 9.3229
# Epoch31: loss: 0.5548 val_loss: 10.1725
# Epoch32: loss: 0.5307 val_loss: 8.0614
# Epoch33: loss: 0.3789 val_loss: 11.1377
# Epoch34: loss: 0.4248 val_loss: 5.4964
# Epoch35: loss: 0.4444 val_loss: 10.0257
# Epoch36: loss: 0.3469 val_loss: 7.3034
# Epoch37: loss: 0.3914 val_loss: 7.3686
# Epoch38: loss: 0.3855 val_loss: 8.9069
# Epoch39: loss: 0.4034 val_loss: 10.4896
# Epoch40: loss: 0.5646 val_loss: 9.8418
# Epoch41: loss: 0.4436 val_loss: 7.0129
# Epoch42: loss: 0.4306 val_loss: 7.8811
# Epoch43: loss: 0.4004 val_loss: 9.9147
# Epoch44: loss: 0.4925 val_loss: 7.2179
# Epoch45: loss: 0.3564 val_loss: 7.9901
# Epoch46: loss: 0.2485 val_loss: 10.9838
# Epoch47: loss: 0.2606 val_loss: 9.7855
# Epoch48: loss: 2.1653 val_loss: 8.9829
# Epoch49: loss: 1.9122 val_loss: 7.3989
# Epoch50: loss: 1.5865 val_loss: 11.3747
# Epoch51: loss: 1.1551 val_loss: 11.4464
# Epoch52: loss: 0.9654 val_loss: 10.9063
# Epoch53: loss: 1.2054 val_loss: 8.2537
# Epoch54: loss: 0.7263 val_loss: 9.9550
# Epoch55: loss: 0.5955 val_loss: 9.6791
# Early stopped training at epoch 55
# Accuracy of the network on the 318 train images: 98.7 %
# Accuracy of the network on the 24 val images: 58.3 %
# fold: 2 done!
# <class 'generator'>
# Epoch1: loss: 12.9408 val_loss: 5.8220
# Epoch2: loss: 9.2658 val_loss: 5.8509
# Epoch3: loss: 8.6019 val_loss: 5.5045
# Epoch4: loss: 6.7492 val_loss: 4.1291
# Epoch5: loss: 5.6764 val_loss: 3.8948
# Epoch6: loss: 4.6977 val_loss: 3.9812
# Epoch7: loss: 4.2351 val_loss: 4.1850
# Epoch8: loss: 3.2834 val_loss: 5.7949
# Epoch9: loss: 3.0441 val_loss: 6.8555
# Epoch10: loss: 3.0357 val_loss: 7.1994
# Epoch11: loss: 2.4968 val_loss: 4.3997
# Epoch12: loss: 3.9460 val_loss: 6.9178
# Epoch13: loss: 4.0865 val_loss: 4.4905
# Epoch14: loss: 2.2291 val_loss: 6.3398
# Epoch15: loss: 1.8760 val_loss: 3.2644
# Epoch16: loss: 1.6773 val_loss: 4.4139
# Epoch17: loss: 1.4232 val_loss: 3.8581
# Epoch18: loss: 1.8024 val_loss: 4.4961
# Epoch19: loss: 1.5956 val_loss: 7.5463
# Epoch20: loss: 2.0962 val_loss: 5.8706
# Epoch21: loss: 1.4617 val_loss: 4.0328
# Epoch22: loss: 1.4114 val_loss: 6.6300
# Epoch23: loss: 2.1457 val_loss: 5.1023
# Epoch24: loss: 2.4773 val_loss: 7.4111
# Epoch25: loss: 1.6569 val_loss: 6.9844
# Epoch26: loss: 1.2621 val_loss: 3.8042
# Epoch27: loss: 1.2089 val_loss: 3.8982
# Epoch28: loss: 1.1023 val_loss: 2.6369
# Epoch29: loss: 0.9749 val_loss: 4.2699
# Epoch30: loss: 1.1325 val_loss: 6.6888
# Epoch31: loss: 1.6129 val_loss: 4.5781
# Epoch32: loss: 0.9120 val_loss: 4.7026
# Epoch33: loss: 1.2341 val_loss: 5.5581
# Epoch34: loss: 0.7430 val_loss: 3.5972
# Epoch35: loss: 0.9087 val_loss: 5.7036
# Epoch36: loss: 1.1039 val_loss: 3.3091
# Epoch37: loss: 0.9711 val_loss: 4.8265
# Epoch38: loss: 1.1878 val_loss: 2.8769
# Epoch39: loss: 1.2325 val_loss: 5.8301
# Epoch40: loss: 0.8929 val_loss: 5.9317
# Epoch41: loss: 1.2351 val_loss: 3.1406
# Epoch42: loss: 3.3031 val_loss: 3.6615
# Epoch43: loss: 2.3313 val_loss: 4.8718
# Epoch44: loss: 3.7432 val_loss: 6.8736
# Epoch45: loss: 2.2569 val_loss: 3.3799
# Epoch46: loss: 1.3755 val_loss: 4.1787
# Epoch47: loss: 0.8550 val_loss: 5.0350
# Epoch48: loss: 1.0402 val_loss: 8.2046
# Epoch49: loss: 0.6505 val_loss: 3.9418
# Early stopped training at epoch 49
# Accuracy of the network on the 315 train images: 98.4 %
# Accuracy of the network on the 24 val images: 79.2 %
# fold: 3 done!
# <class 'generator'>
# Epoch1: loss: 17.1275 val_loss: 7.8550
# Epoch2: loss: 9.8279 val_loss: 5.7498
# Epoch3: loss: 7.9957 val_loss: 5.2133
# Epoch4: loss: 6.8760 val_loss: 6.6442
# Epoch5: loss: 6.3197 val_loss: 5.2122
# Epoch6: loss: 6.0145 val_loss: 5.7379
# Epoch7: loss: 5.4121 val_loss: 4.8570
# Epoch8: loss: 4.7712 val_loss: 4.8268
# Epoch9: loss: 3.8584 val_loss: 5.3665
# Epoch10: loss: 3.2054 val_loss: 5.3497
# Epoch11: loss: 2.5634 val_loss: 5.3435
# Epoch12: loss: 2.6313 val_loss: 5.2984
# Epoch13: loss: 1.7148 val_loss: 4.8830
# Epoch14: loss: 2.1209 val_loss: 6.2189
# Epoch15: loss: 1.8152 val_loss: 5.2957
# Epoch16: loss: 2.1905 val_loss: 5.8982
# Epoch17: loss: 2.2999 val_loss: 4.6797
# Epoch18: loss: 1.6571 val_loss: 6.0794
# Epoch19: loss: 1.4414 val_loss: 4.5846
# Epoch20: loss: 1.2279 val_loss: 5.6007
# Epoch21: loss: 0.9917 val_loss: 4.2283
# Epoch22: loss: 0.9744 val_loss: 4.7896
# Epoch23: loss: 1.2969 val_loss: 4.4087
# Epoch24: loss: 1.0018 val_loss: 5.0749
# Epoch25: loss: 0.9542 val_loss: 4.8027
# Epoch26: loss: 0.8798 val_loss: 5.3213
# Epoch27: loss: 1.0087 val_loss: 6.9332
# Epoch28: loss: 1.3650 val_loss: 6.1293
# Epoch29: loss: 0.8534 val_loss: 4.3123
# Epoch30: loss: 1.4139 val_loss: 7.1617
# Epoch31: loss: 1.1652 val_loss: 5.9134
# Epoch32: loss: 0.6238 val_loss: 4.8145
# Epoch33: loss: 0.7086 val_loss: 5.1884
# Epoch34: loss: 0.6838 val_loss: 3.9587
# Epoch35: loss: 0.5356 val_loss: 4.2996
# Epoch36: loss: 1.1045 val_loss: 5.0144
# Epoch37: loss: 0.8528 val_loss: 5.1571
# Epoch38: loss: 0.5880 val_loss: 4.4968
# Epoch39: loss: 0.6687 val_loss: 5.2850
# Epoch40: loss: 0.5163 val_loss: 5.7837
# Epoch41: loss: 0.4359 val_loss: 5.5540
# Epoch42: loss: 0.4672 val_loss: 5.1593
# Epoch43: loss: 1.1356 val_loss: 4.5391
# Epoch44: loss: 1.2283 val_loss: 3.6103
# Epoch45: loss: 1.0890 val_loss: 7.1415
# Epoch46: loss: 1.0610 val_loss: 5.2930
# Epoch47: loss: 0.6409 val_loss: 4.2783
# Epoch48: loss: 0.8324 val_loss: 8.9543
# Epoch49: loss: 0.9626 val_loss: 4.6518
# Epoch50: loss: 0.7701 val_loss: 5.5829
# Epoch51: loss: 0.8858 val_loss: 5.7257
# Epoch52: loss: 0.3963 val_loss: 6.2252
# Epoch53: loss: 0.4126 val_loss: 6.6379
# Epoch54: loss: 1.2235 val_loss: 6.8393
# Epoch55: loss: 1.7562 val_loss: 6.0816
# Epoch56: loss: 1.2332 val_loss: 7.4937
# Epoch57: loss: 1.0723 val_loss: 4.2812
# Epoch58: loss: 0.5712 val_loss: 4.8159
# Epoch59: loss: 0.3298 val_loss: 5.0979
# Epoch60: loss: 0.2381 val_loss: 4.2606
# Epoch61: loss: 0.2423 val_loss: 4.5224
# Epoch62: loss: 0.1693 val_loss: 5.3189
# Epoch63: loss: 0.2300 val_loss: 5.5689
# Epoch64: loss: 0.2634 val_loss: 5.5982
# Epoch65: loss: 0.2611 val_loss: 5.6301
# Early stopped training at epoch 65
# Accuracy of the network on the 315 train images: 99.4 %
# Accuracy of the network on the 24 val images: 70.8 %
# fold: 4 done!
# <class 'generator'>
# Epoch1: loss: 13.8666 val_loss: 3.8735
# Epoch2: loss: 8.7424 val_loss: 3.6649
# Epoch3: loss: 7.1234 val_loss: 4.0678
# Epoch4: loss: 6.3211 val_loss: 3.6377
# Epoch5: loss: 5.4114 val_loss: 2.9097
# Epoch6: loss: 4.5926 val_loss: 4.7907
# Epoch7: loss: 4.3862 val_loss: 3.2616
# Epoch8: loss: 4.0374 val_loss: 3.5498
# Epoch9: loss: 3.7991 val_loss: 2.9173
# Epoch10: loss: 3.1381 val_loss: 2.6760
# Epoch11: loss: 2.8467 val_loss: 3.5328
# Epoch12: loss: 2.8484 val_loss: 3.2750
# Epoch13: loss: 2.1736 val_loss: 3.5559
# Epoch14: loss: 2.1487 val_loss: 3.4967
# Epoch15: loss: 2.4264 val_loss: 4.4979
# Epoch16: loss: 2.6845 val_loss: 4.4607
# Epoch17: loss: 1.9792 val_loss: 3.5402
# Epoch18: loss: 1.9706 val_loss: 4.5936
# Epoch19: loss: 2.1150 val_loss: 5.0925
# Epoch20: loss: 1.8899 val_loss: 4.7779
# Epoch21: loss: 1.5428 val_loss: 4.6882
# Epoch22: loss: 1.4496 val_loss: 3.0895
# Epoch23: loss: 1.2873 val_loss: 3.6317
# Epoch24: loss: 1.1141 val_loss: 2.7602
# Epoch25: loss: 1.3274 val_loss: 4.7066
# Epoch26: loss: 1.0821 val_loss: 2.7138
# Epoch27: loss: 0.9339 val_loss: 5.1613
# Epoch28: loss: 0.8472 val_loss: 4.0329
# Epoch29: loss: 0.8854 val_loss: 3.0356
# Epoch30: loss: 1.0067 val_loss: 3.1055
# Epoch31: loss: 1.0168 val_loss: 4.3230
# Early stopped training at epoch 31
# Accuracy of the network on the 315 train images: 97.8 %
# Accuracy of the network on the 23 val images: 73.9 %
# fold: 5 done!
# <class 'generator'>
# Epoch1: loss: 13.0900 val_loss: 10.0151
# Epoch2: loss: 8.8288 val_loss: 9.0739
# Epoch3: loss: 8.2266 val_loss: 9.1083
# Epoch4: loss: 7.3775 val_loss: 7.5286
# Epoch5: loss: 7.1265 val_loss: 5.8583
# Epoch6: loss: 5.6095 val_loss: 6.8977
# Epoch7: loss: 4.4609 val_loss: 7.1600
# Epoch8: loss: 3.7337 val_loss: 6.7988
# Epoch9: loss: 3.7265 val_loss: 8.2026
# Epoch10: loss: 3.5453 val_loss: 9.1715
# Epoch11: loss: 2.7368 val_loss: 5.7236
# Epoch12: loss: 2.5817 val_loss: 3.9151
# Epoch13: loss: 2.2332 val_loss: 4.8384
# Epoch14: loss: 2.1357 val_loss: 5.2865
# Epoch15: loss: 2.2117 val_loss: 5.2245
# Epoch16: loss: 2.3143 val_loss: 8.0505
# Epoch17: loss: 2.0878 val_loss: 7.5039
# Epoch18: loss: 1.5001 val_loss: 4.4844
# Epoch19: loss: 1.5039 val_loss: 2.5650
# Epoch20: loss: 2.5921 val_loss: 6.0869
# Epoch21: loss: 2.1343 val_loss: 4.8293
# Epoch22: loss: 1.7633 val_loss: 3.5007
# Epoch23: loss: 1.3964 val_loss: 4.5515
# Epoch24: loss: 1.3309 val_loss: 4.5549
# Epoch25: loss: 1.1024 val_loss: 7.0189
# Epoch26: loss: 1.2814 val_loss: 3.5843
# Epoch27: loss: 1.6487 val_loss: 4.6240
# Epoch28: loss: 0.9963 val_loss: 5.2582
# Epoch29: loss: 0.8738 val_loss: 6.4561
# Epoch30: loss: 0.8617 val_loss: 4.9613
# Epoch31: loss: 0.6426 val_loss: 4.4339
# Epoch32: loss: 0.6133 val_loss: 8.5481
# Epoch33: loss: 0.9349 val_loss: 4.2636
# Epoch34: loss: 0.7230 val_loss: 4.3572
# Epoch35: loss: 0.9605 val_loss: 4.2132
# Epoch36: loss: 0.7574 val_loss: 6.5310
# Epoch37: loss: 0.6176 val_loss: 3.0659
# Epoch38: loss: 0.6005 val_loss: 4.9291
# Epoch39: loss: 0.5354 val_loss: 5.3921
# Epoch40: loss: 0.4151 val_loss: 3.7874
# Early stopped training at epoch 40
# Accuracy of the network on the 315 train images: 98.7 %
# Accuracy of the network on the 23 val images: 82.6 %
# fold: 6 done!
# <class 'generator'>
# Epoch1: loss: 15.4790 val_loss: 11.0458
# Epoch2: loss: 11.1354 val_loss: 7.4948
# Epoch3: loss: 8.9349 val_loss: 6.8359
# Epoch4: loss: 7.6153 val_loss: 8.3296
# Epoch5: loss: 6.8280 val_loss: 6.6408
# Epoch6: loss: 6.3014 val_loss: 7.7139
# Epoch7: loss: 5.4471 val_loss: 5.6056
# Epoch8: loss: 4.6619 val_loss: 5.6339
# Epoch9: loss: 4.4083 val_loss: 5.3205
# Epoch10: loss: 4.7206 val_loss: 6.3497
# Epoch11: loss: 4.0812 val_loss: 4.5209
# Epoch12: loss: 3.5352 val_loss: 7.0432
# Epoch13: loss: 2.6230 val_loss: 6.2118
# Epoch14: loss: 3.0883 val_loss: 5.8614
# Epoch15: loss: 2.6856 val_loss: 5.0745
# Epoch16: loss: 2.1911 val_loss: 5.7655
# Epoch17: loss: 2.7862 val_loss: 7.3020
# Epoch18: loss: 3.6850 val_loss: 6.2013
# Epoch19: loss: 1.9061 val_loss: 6.5110
# Epoch20: loss: 1.3349 val_loss: 6.6076
# Epoch21: loss: 1.2599 val_loss: 6.2185
# Epoch22: loss: 1.1123 val_loss: 6.3620
# Epoch23: loss: 1.6646 val_loss: 4.8658
# Epoch24: loss: 1.5499 val_loss: 5.0873
# Epoch25: loss: 1.2160 val_loss: 6.1299
# Epoch26: loss: 0.9055 val_loss: 6.3352
# Epoch27: loss: 0.8598 val_loss: 4.6254
# Epoch28: loss: 0.8102 val_loss: 6.5426
# Epoch29: loss: 0.7455 val_loss: 6.8247
# Epoch30: loss: 0.6162 val_loss: 4.4497
# Epoch31: loss: 0.8324 val_loss: 6.3162
# Epoch32: loss: 0.5993 val_loss: 5.4060
# Epoch33: loss: 0.5648 val_loss: 4.8334
# Epoch34: loss: 0.9977 val_loss: 5.5496
# Epoch35: loss: 0.9451 val_loss: 5.4757
# Epoch36: loss: 0.8437 val_loss: 6.5682
# Epoch37: loss: 0.6275 val_loss: 6.0587
# Epoch38: loss: 0.6805 val_loss: 4.0493
# Epoch39: loss: 0.8630 val_loss: 6.0016
# Epoch40: loss: 0.5644 val_loss: 6.2489
# Epoch41: loss: 0.3666 val_loss: 4.1301
# Epoch42: loss: 0.3441 val_loss: 5.2102
# Epoch43: loss: 0.3707 val_loss: 5.7132
# Epoch44: loss: 0.6253 val_loss: 5.8702
# Epoch45: loss: 0.4245 val_loss: 5.8816
# Epoch46: loss: 0.7938 val_loss: 4.7525
# Epoch47: loss: 1.2423 val_loss: 6.3956
# Epoch48: loss: 1.6720 val_loss: 4.5123
# Epoch49: loss: 1.0975 val_loss: 5.9691
# Epoch50: loss: 0.4271 val_loss: 6.4856
# Epoch51: loss: 0.5542 val_loss: 5.1198
# Epoch52: loss: 0.2636 val_loss: 5.9284
# Epoch53: loss: 0.2841 val_loss: 5.1002
# Epoch54: loss: 0.2736 val_loss: 5.2900
# Epoch55: loss: 0.1925 val_loss: 6.0636
# Epoch56: loss: 0.1767 val_loss: 5.9038
# Epoch57: loss: 0.1754 val_loss: 6.1982
# Epoch58: loss: 0.1796 val_loss: 5.5818
# Epoch59: loss: 0.1787 val_loss: 6.1368
# Early stopped training at epoch 59
# Accuracy of the network on the 315 train images: 99.4 %
# Accuracy of the network on the 23 val images: 73.9 %
# fold: 7 done!
# <class 'generator'>
# Epoch1: loss: 18.6984 val_loss: 10.1237
# Epoch2: loss: 9.3654 val_loss: 7.3787
# Epoch3: loss: 8.0196 val_loss: 9.0122
# Epoch4: loss: 6.5464 val_loss: 8.7987
# Epoch5: loss: 5.7053 val_loss: 10.4904
# Epoch6: loss: 5.1162 val_loss: 8.8434
# Epoch7: loss: 4.4248 val_loss: 8.7576
# Epoch8: loss: 3.4412 val_loss: 8.4252
# Epoch9: loss: 2.7275 val_loss: 8.0090
# Epoch10: loss: 2.4887 val_loss: 8.7991
# Epoch11: loss: 3.4101 val_loss: 10.0091
# Epoch12: loss: 3.3376 val_loss: 8.5747
# Epoch13: loss: 2.4026 val_loss: 8.3620
# Epoch14: loss: 1.8461 val_loss: 7.2570
# Epoch15: loss: 1.3376 val_loss: 7.3010
# Epoch16: loss: 1.2485 val_loss: 8.3173
# Epoch17: loss: 1.2703 val_loss: 7.7929
# Epoch18: loss: 1.2514 val_loss: 6.7869
# Epoch19: loss: 1.1744 val_loss: 7.5508
# Epoch20: loss: 1.3140 val_loss: 8.0732
# Epoch21: loss: 1.0213 val_loss: 8.6654
# Epoch22: loss: 1.1957 val_loss: 7.3157
# Epoch23: loss: 0.9474 val_loss: 8.5377
# Epoch24: loss: 0.8272 val_loss: 8.1253
# Epoch25: loss: 0.6778 val_loss: 7.3127
# Epoch26: loss: 0.5967 val_loss: 7.4978
# Epoch27: loss: 1.0918 val_loss: 6.6850
# Epoch28: loss: 0.6903 val_loss: 7.4937
# Epoch29: loss: 0.5602 val_loss: 6.4077
# Epoch30: loss: 0.7327 val_loss: 6.4073
# Epoch31: loss: 0.8819 val_loss: 8.6472
# Epoch32: loss: 0.8198 val_loss: 7.6388
# Epoch33: loss: 0.7796 val_loss: 8.0918
# Epoch34: loss: 0.6368 val_loss: 8.8035
# Epoch35: loss: 0.8645 val_loss: 9.2796
# Epoch36: loss: 0.3464 val_loss: 7.1912
# Epoch37: loss: 0.3515 val_loss: 6.9259
# Epoch38: loss: 0.2651 val_loss: 6.1456
# Epoch39: loss: 0.2938 val_loss: 8.4145
# Epoch40: loss: 0.2819 val_loss: 7.8603
# Epoch41: loss: 0.2534 val_loss: 7.6092
# Epoch42: loss: 0.4380 val_loss: 8.3373
# Epoch43: loss: 0.7328 val_loss: 6.6919
# Epoch44: loss: 0.5521 val_loss: 7.2085
# Epoch45: loss: 0.7103 val_loss: 7.6125
# Epoch46: loss: 1.8248 val_loss: 9.8067
# Epoch47: loss: 1.8638 val_loss: 8.7434
# Epoch48: loss: 0.9035 val_loss: 8.5035
# Epoch49: loss: 0.5505 val_loss: 9.5573
# Epoch50: loss: 0.7031 val_loss: 10.8500
# Epoch51: loss: 0.7559 val_loss: 7.5601
# Epoch52: loss: 1.0594 val_loss: 7.3423
# Epoch53: loss: 1.3142 val_loss: 8.7661
# Epoch54: loss: 0.7887 val_loss: 8.8222
# Epoch55: loss: 0.4271 val_loss: 8.0768
# Epoch56: loss: 0.3589 val_loss: 8.6432
# Epoch57: loss: 0.4860 val_loss: 7.1938
# Epoch58: loss: 1.7693 val_loss: 10.4292
# Epoch59: loss: 1.0765 val_loss: 7.1285
# Early stopped training at epoch 59
# Accuracy of the network on the 315 train images: 97.5 %
# Accuracy of the network on the 23 val images: 60.9 %
# fold: 8 done!
# <class 'generator'>
# Epoch1: loss: 13.3087 val_loss: 6.7968
# Epoch2: loss: 8.4592 val_loss: 6.5442
# Epoch3: loss: 7.2648 val_loss: 5.8374
# Epoch4: loss: 6.6513 val_loss: 6.1169
# Epoch5: loss: 5.7305 val_loss: 6.2506
# Epoch6: loss: 5.7985 val_loss: 6.1474
# Epoch7: loss: 4.8166 val_loss: 5.6747
# Epoch8: loss: 4.0094 val_loss: 6.1600
# Epoch9: loss: 3.7674 val_loss: 5.6350
# Epoch10: loss: 3.0303 val_loss: 6.0141
# Epoch11: loss: 2.7875 val_loss: 7.1715
# Epoch12: loss: 2.5214 val_loss: 4.9223
# Epoch13: loss: 1.9346 val_loss: 6.2650
# Epoch14: loss: 2.1241 val_loss: 5.3758
# Epoch15: loss: 1.5244 val_loss: 5.5630
# Epoch16: loss: 2.8064 val_loss: 6.6120
# Epoch17: loss: 2.8260 val_loss: 6.7492
# Epoch18: loss: 2.4099 val_loss: 7.3645
# Epoch19: loss: 1.9800 val_loss: 5.3667
# Epoch20: loss: 1.2884 val_loss: 4.7537
# Epoch21: loss: 2.0659 val_loss: 6.6611
# Epoch22: loss: 2.1526 val_loss: 6.1305
# Epoch23: loss: 1.1795 val_loss: 5.1341
# Epoch24: loss: 0.9581 val_loss: 5.7413
# Epoch25: loss: 1.0171 val_loss: 5.5059
# Epoch26: loss: 0.9140 val_loss: 5.3201
# Epoch27: loss: 0.9895 val_loss: 8.1188
# Epoch28: loss: 0.7805 val_loss: 5.8471
# Epoch29: loss: 0.4349 val_loss: 5.2608
# Epoch30: loss: 0.5000 val_loss: 5.4841
# Epoch31: loss: 0.3272 val_loss: 6.1618
# Epoch32: loss: 0.3153 val_loss: 5.5139
# Epoch33: loss: 0.2544 val_loss: 5.7212
# Epoch34: loss: 0.3098 val_loss: 5.8581
# Epoch35: loss: 0.3398 val_loss: 5.4483
# Epoch36: loss: 0.5925 val_loss: 6.6078
# Epoch37: loss: 0.9700 val_loss: 7.0058
# Epoch38: loss: 0.6695 val_loss: 5.5615
# Epoch39: loss: 0.8665 val_loss: 6.6231
# Epoch40: loss: 0.5974 val_loss: 5.9122
# Epoch41: loss: 0.5249 val_loss: 8.0367
# Early stopped training at epoch 41
# Accuracy of the network on the 318 train images: 98.4 %
# Accuracy of the network on the 23 val images: 60.9 %
# fold: 9 done!

# %% [markdown]
# # 4. Test Models

# %%
class MLP(nn.Module):
    def __init__(self, l1=120, l2=84, p = 0.2):
        super(MLP, self).__init__()
        self.fc1 = nn.Linear(100, l1)
        self.fc2 = nn.Linear(l1, l2)
        self.fc3 = nn.Linear(l2, 3)
        self.activ = torch.nn.Sigmoid()
        self.dropout = nn.Dropout(p)

    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.dropout(x)
        x = self.fc3(x)
        return self.activ(x)

l1, l2, p = 600, 150, 0.35
trained_model = model = MLP(l1, l2, p).to(device)

# %%
#trained_model = pretrained_model()
root_path = f'nnrank/ImageNet/aug3/MLP'

best_test, confusion_matrix_test = mlp_nnrank_cross_val_final_test(trained_model, test_X, test_Y, 'test', root_path)


print(best_test)
print(f'test_acc_mean: {np.mean(best_test) :.3f}, std: {np.std(best_test) :.3f}')
print("......")

def cm_to_plot(best_test):

    max_test = np.max(best_test)
    idx_cm = []
    for index, item in enumerate(best_test):
        if item == max_test:
            idx_cm.append(index)

    print('idx_cm: ', idx_cm)
    print('max_test_acc: ', max_test)

    print(confusion_matrix_test[idx_cm[0]])
cm_to_plot(best_test)
print('5th confusion matrix: ', [list(item) for item in confusion_matrix_test[4]])


cm_list = []
for cm in confusion_matrix_test:
    cm_list.append([list(item) for item in cm])
#print(cm_list)

print(len(cm_list))
print('avg cm: ', [list(item) for item in np.mean(cm_list, axis=0)])
# Out:
# Accuracy of the network on the 27 test images: 70.4 %
# Accuracy of the network on the 27 test images: 59.3 %
# Accuracy of the network on the 27 test images: 70.4 %
# Accuracy of the network on the 27 test images: 77.8 %
# Accuracy of the network on the 27 test images: 74.1 %
# Accuracy of the network on the 27 test images: 77.8 %
# Accuracy of the network on the 27 test images: 77.8 %
# Accuracy of the network on the 27 test images: 77.8 %
# Accuracy of the network on the 27 test images: 59.3 %
# Accuracy of the network on the 27 test images: 66.7 %
# [70.37037037037037, 59.25925925925926, 70.37037037037037, 77.77777777777777, 74.07407407407408, 77.77777777777777, 77.77777777777777, 77.77777777777777, 59.25925925925926, 66.66666666666667]
# test_acc_mean: 71.111, std: 6.988
# ......
# idx_cm:  [3, 5, 6, 7]
# max_test_acc:  77.77777777777777
# [[ 1  2  0]
#  [ 0 10  3]
#  [ 0  1 10]]
# 5th confusion matrix:  [[1, 2, 0], [2, 8, 3], [0, 0, 11]]
# 10
# avg cm:  [[1.0, 1.9, 0.1], [1.6, 8.9, 2.5], [0.0, 1.7, 9.3]]
